# %%
# %run main.ipynb

# %%
from IPython.display import HTML
import plotly.io as pio
pio.renderers.default = "svg"

# %%
df = get_data_df()

# %%
year_list = ['2020','2021', '2022']
sub_df = df[df['year'].isin(year_list)]

# %%
fig = px.line(sub_df, x='i_date', y=["new_confirmed_cases", "new_death_cases", "total_death_toll"])
fig.show(width=1600, height=400)
#HTML(fig.to_html())

# %%
fig = px.line(sub_df, x='i_date', y=["new_death_cases"])
fig.show(width=1600, height=400)

# %%
df.tail(11)
# Out:
#    org_date      i_date date month  year total_confirmed_cases  \
# 0  12/30/21  30-12-2021   30    12  2021              34838804
# 0  12/31/21  31-12-2021   31    12  2021              34861579
# 0    1/1/22  01-01-2022   01    01  2022              34889132
# 0    1/2/22  02-01-2022   02    01  2022              34922882
# 0    1/3/22  03-01-2022   03    01  2022              34960261
# 0    1/4/22  04-01-2022   04    01  2022              35018358
# 0    1/5/22  05-01-2022   05    01  2022              35109286
# 0    1/6/22  06-01-2022   06    01  2022              35226386
# 0    1/7/22  07-01-2022   07    01  2022              35368372
# 0    1/8/22  08-01-2022   08    01  2022              35528004
# 0    1/9/22  09-01-2022   09    01  2022              35707727
#
#   new_confirmed_cases new_death_cases total_death_toll
# 0               16764             220           481080
# 0               22775             406           481486
# ...
